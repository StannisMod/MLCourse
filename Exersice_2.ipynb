# %%
import pandas as pd

df = pd.read_csv('data/2/37_25.csv', names=[str(i) for i in range(10)])
df
# Out:
#             0          1          2          3          4          5  \
# 0   23.665571  -1.280670 -13.474581   2.473841   3.979925   8.653313
# 1  -21.020432 -19.607652 -19.380266  -5.940952  16.866378  21.314366
# 2  -24.340983 -18.228900 -19.565034  -7.199030  18.566760  22.248139
# 3   21.573498  -1.195482 -13.662428   1.265740   7.282422  10.859079
# 4   14.192738 -14.180659  -6.515671   5.965425 -21.594373  15.308063
# 5  -22.034241 -18.123628 -18.097000  -5.409511  14.084550  19.728083
# 6   21.907821  -2.241633 -16.950150   4.948109   6.199294   7.660586
# 7  -22.250413 -17.355181 -15.238117  -5.854727  15.268017  18.995714
# 8  -20.541075 -17.077875 -16.962968  -5.988675  17.674647  22.746000
# 9   21.074523  -1.345694 -12.663183   2.738254   7.809359   7.820627
# 10 -26.463233  -1.712249  -5.588029   1.673835  23.165109  19.450133
# 11  13.010998 -16.046377  -6.471133   6.291418 -22.581895  16.050787
# 12  14.250765   6.706139  -2.997878  21.884599  17.526106 -16.525400
# ...

# %%
from sklearn.decomposition import PCA
import numpy as np

pca = PCA(n_components=2, svd_solver='full')
transformed = pca.fit_transform(df)
np.round(transformed[0], 3)
# Out:
# array([-28.204, -11.473])

# %%
explained_variance = np.round(np.cumsum(pca.explained_variance_ratio_), 3)
explained_variance
# Out:
# array([0.391, 0.704])

# %%
pca = PCA(n_components=10, svd_solver='full')
df_full = pca.fit_transform(df)
explained_variance = np.round(np.cumsum(pca.explained_variance_ratio_), 3)
explained_variance
# Out:
# array([0.391, 0.704, 0.926, 0.994, 0.995, 0.996, 0.997, 0.998, 0.999,
#        1.   ])

# %%
from matplotlib import pyplot as plt

plt.plot(transformed[:101, 0], transformed[:101, 1], 'o', markerfacecolor='red', markeredgecolor='k', markersize=8)

# %%
scores = np.genfromtxt('data/2/X_reduced_441.csv', delimiter=';')
loadings = np.genfromtxt('data/2/X_loadings_441.csv', delimiter=';')
values = np.dot(scores, loadings.T)
plt.imshow(values, cmap='Greys_r')
